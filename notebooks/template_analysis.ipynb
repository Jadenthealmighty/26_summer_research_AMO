# %% [markdown]
# # [Experiment Title]
#
# **Date:**
# **Author:**
# **Description:** Brief description of what this notebook analyses.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal, optimize

import sys
sys.path.insert(0, '../src')
from data_utils import load_npy, load_csv, save_npy, save_csv, list_data_files
from plot_utils import set_style, save_figure

set_style(font_size=12)
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
# Example: list available files
list_data_files('raw', '*.csv')

# %% [markdown]
# ## 2. Analysis

# %%
# Your analysis here

# %% [markdown]
# ## 3. Figures

# %%
fig, ax = plt.subplots(figsize=(6, 4))
# ax.plot(...)
ax.set_xlabel('x label [units]')
ax.set_ylabel('y label [units]')
ax.set_title('Figure title')
plt.tight_layout()
# save_figure(fig, 'descriptive_name')
plt.show()

# %% [markdown]
# ## 4. Summary / Notes

# %% [markdown]
# - Key finding 1
# - Key finding 2
